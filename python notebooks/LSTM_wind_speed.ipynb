# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive
# Out:
# /content/drive

# %%
cd My Drive
# Out:
# /content/drive/My Drive

# %%
dataframe=pd.read_csv('OWM.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-33055344fab2> in <module>()
# ----> 1 dataframe=pd.read_csv('OWM.csv')
#
# NameError: name 'pd' is not defined

# %%
dataframe.head()  #4june2020 
#data set is collected from 26june2020 to 4 july2020 by calling open weather api
# Out:
#    clouds  dew_point  ...  mean_wind_deg                  time
# 0      11     292.12  ...            270  01/19/1970  10:48:43
# 1      53     292.56  ...            270  01/19/1970  10:48:46
# 2      80     293.21  ...            270  01/19/1970  10:48:50
# 3      74     293.43  ...            270  01/19/1970  10:48:54
# 4      70     293.65  ...            270  01/19/1970  10:48:57
#
# [5 rows x 14 columns]

# %%
data= dataframe

# %%
data.head()
# Out:
#    Unnamed: 0  clouds  dew_point  ...     main     description   icon
# 0           0      11     292.12  ...   Clouds      few clouds    02d
# 1           1      53     292.56  ...   Clouds   broken clouds    04d
# 2           2      80     293.21  ...   Clouds   broken clouds    04n
# 3           3      74     293.43  ...   Clouds   broken clouds    04n
# 4           4      70     293.65  ...   Clouds   broken clouds    04n
#
# [5 rows x 19 columns]

# %%
# load dataset
#dataset = read_csv('pollution.csv', header=0, index_col=0)
req_dataset=data[['humidity','pressure','temp','wind_deg','wind_speed(m/s)','mean_WindSpeed(m/s)','mean_wind_deg']]
values = req_dataset.values
# specify columns to plot
groups = [0, 1, 2, 3,4,5,6]
i = 1
# plot each column
#plt.figure()
plt.figure(figsize=(20,10))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(req_dataset.columns[group], y=0.5, loc='right')
    i += 1

plt.show()

# %%
#target_names = ['humidity','pressure','temp','wind_deg','wind_speed(m/s)','mean_WindSpeed(m/s)','mean_wind_deg']
target_names=['wind_speed(m/s)']

# %%
len(data)/48
# Out:
# 154.0

# %%
shift_hours = 1
shift_steps = shift_hours * 1*48

# %%
df_targets = data[target_names]

# %%
import sys
import numpy
numpy.set_printoptions(threshold=50)

# %%
df_targets
# Out:
#       wind_speed(m/s)
# 0                7.47
# 1                7.16
# 2                5.63
# 3                5.51
# 4                4.98
# ...               ...
# 7387             6.83
# 7388             6.92
# 7389             7.18
# 7390             7.46
# 7391             7.58
#
# [7392 rows x 1 columns]

# %%
#x_data=df_targets.values[0:-shift_steps]

# %%
#x_data.shape

# %%
#y_data = df_targets.values[:-shift_steps]

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)
# fix random seed for reproducibility
np.random.seed(7)
# load the dataset

# %%
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
df_targets = scaler.fit_transform(df_targets)
# split into train and test sets
train_size = int(len(df_targets) * 0.67)
test_size = len(df_targets) - train_size
train, test = df_targets[0:train_size,:], df_targets[train_size:len(df_targets),:]

# %%
len(train)
# Out:
# 4952

# %%
len(test)
# Out:
# 2440

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
print(trainX[:,:,0])
# Out:
# [[0.83571429]
#  [0.79880952]
#  [0.61666667]
#  ...
#  [0.60714286]
#  [0.6       ]
#  [0.51785714]]

# %%
print(trainY.shape)
# Out:
# (4950, 1)

# %%
'''import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)'''
# Out:
# 'import sys\nimport numpy\nnumpy.set_printoptions(threshold=sys.maxsize)'

# %%
trainY
# Out:
# array([[0.79880952],
#        [0.61666667],
#        [0.60238095],
#        ...,
#        [0.6       ],
#        [0.51785714],
#        [0.45357143]])

# %%
trainX.shape
# Out:
# (4950, 1, 1)

# %%
trainY.shape
# Out:
# (4950, 1)

# %%
testX.shape
# Out:
# (2438, 1, 1)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0137
# Epoch 2/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 3/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 4/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 5/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 6/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 7/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 8/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 9/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0048
# Epoch 10/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 11/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 12/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 13/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 14/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 15/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 16/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 17/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 18/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 19/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 20/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 21/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 22/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 23/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 24/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 25/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 26/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 27/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 28/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 29/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 30/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 31/100
# 4950/4950 [==============================] - 9s 2ms/step - loss: 0.0047
# Epoch 32/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 33/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 34/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 35/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 36/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 37/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 38/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 39/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 40/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 41/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 42/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 43/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 44/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 45/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 46/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 47/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 48/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 49/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 50/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 51/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 52/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 53/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 54/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 55/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 56/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 57/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 58/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 59/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 60/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 61/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 62/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 63/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 64/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 65/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 66/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 67/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 68/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 69/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 70/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 71/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 72/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 73/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 74/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 75/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 76/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 77/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 78/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 79/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 80/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 81/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 82/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 83/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 84/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 85/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 86/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 87/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 88/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 89/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 90/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 91/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 92/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 93/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 94/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 95/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 96/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 97/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 98/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 99/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047
# Epoch 100/100
# 4950/4950 [==============================] - 7s 1ms/step - loss: 0.0047

# %%
model.save_weights("IBM_hack_wind_speed.h5")

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.load_weights("IBM_hack_wind_speed.h5")

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY)

# %%
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY)

# %%
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 0.57 RMSE
# Test Score: 0.56 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(df_targets)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %%
testPredictPlot = np.empty_like(df_targets)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(df_targets)-1, :] = testPredict

# %%
plt.figure(figsize=(20,20))
plt.plot(scaler.inverse_transform(df_targets))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.legend(['Actual','Train prediction','Test prediction'])
plt.show()

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
#for deploying model in android or flutter apps , convert the model to tflite model
import tensorflow as tf

#model = tf.keras.models.load_model('content/drive/My Drive/IBM_hack_wind_speed.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("IBM_hack_wind_speed.tflite", "wb").write(tflite_model)
# Out:
# 12068
